# %% [markdown]
# ## Movies_Recomender_System

# %%
import pandas as pd

# %%
movies = pd.read_csv("/Users/svatipriya/Downloads/top10K-TMDB-movies.csv")

# %%
movies.head().shape
# Out:
# (5, 9)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   genre              9997 non-null   object
#  3   original_language  10000 non-null  object
#  4   overview           9987 non-null   object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies = movies[['id', 'title', 'overview', 'genre']]

# %%
movies
# Out:
#       Unnamed: 0  adult                     backdrop_path  \
# 0              0  False  /jXJxMcVoEuXzym3vFnjqDW4ifo6.jpg
# 1              1  False  /yOm993lsJyPmBodlYjgpPwBjXP9.jpg
# 2              2  False  /ehumsuIBbgAe1hg343oszCLrAfI.jpg
# 3              3  False  /meyhnvssZOPPjud4F1CjOb4snET.jpg
# 4              4  False  /tLxjbT5ROZRwYcpNT3nfQbqkApk.jpg
# ...          ...    ...                               ...
# 9995        9995  False  /xSN7sVwIC6ExQZVMIUMjm4Tl2TN.jpg
# 9996        9996  False  /x4sqnmV2nAKIG6cmt9WAF9xRA2M.jpg
# 9997        9997  False  /gjysasbU9gKgbu7yW7Z1aonoiTg.jpg
# 9998        9998  False  /j3qoYRsQueTCvFhOVakVNhqmxRW.jpg
# 9999        9999  False  /jRwqNjLsOiCzDJ4lT4dpFZemNx7.jpg
#
#                                                  genres       id     imdb_id  \
# 0                    ['Action', 'Adventure', 'Fantasy']   572802   tt9663764
# 1                       ['Comedy', 'Family', 'Fantasy']   787699   tt6166392
# 2       ['Animation', 'Family', 'Fantasy', 'Adventure']  1022796  tt11304740
# 3     ['Animation', 'Adventure', 'Comedy', 'Family',...   940551   tt6495056
# 4            ['Science Fiction', 'Adventure', 'Action']   609681  tt10676048
# ...                                                 ...      ...         ...
# 9995                                   ['Drama', 'War']    10178   tt0046816
# 9996                     ['Comedy', 'Drama', 'Romance']      236   tt0110598
# 9997                             ['Horror', 'Thriller']   517116   tt6535880
# 9998                                 ['Drama', 'Music']   239566   tt2473602
# 9999                                          ['Drama']   826796  tt13649036
#
#      original_language                                           overview  \
# 0                   en  Black Manta, still driven by the need to aveng...
# 1                   en  Willy Wonka – chock-full of ideas and determin...
# 2                   en  Asha, a sharp-witted idealist, makes a wish so...
# 3                   en  After a migrating duck family alights on their...
# 4                   en  Carol Danvers, aka Captain Marvel, has reclaim...
# ...                ...                                                ...
# 9995                en  When a US Naval captain shows signs of mental ...
# 9996                en  A young social outcast in Australia steals mon...
# 9997                en  On Halloween, a group of friends encounter an ...
# 9998                en  A chronicle of James Brown's rise from extreme...
# 9999                en  Sarah seems to have found her calling working ...
#
#       popularity                       poster_path release_date  runtime  \
# 0       5841.384  /7lTnXOy0iNtBAdRP3TZvaKJ77F6.jpg   2023-12-20      124
# 1       2333.391  /qhb1qOilapbapxWQn9jtRCMwXJF.jpg   2023-12-06      117
# 2       1662.711  /AcoVfiv1rrWOmAdpnAMnM56ki19.jpg   2023-11-13       95
# 3       1486.310  /ldfCF9RhR40mppkzmftxapaHeTo.jpg   2023-12-06       83
# 4       1397.918  /9GBhzXMFjgcZ3FdR9w3bUMMTps5.jpg   2023-11-08      105
# ...          ...                               ...          ...      ...
# 9995      12.677  /vuO4Z3wOWVlhq35MS9asZeT9rVp.jpg   1954-06-24      124
# 9996      12.677  /zJyTr8Fo412a2OIfJGXTRAm4IwX.jpg   1994-09-29      106
# 9997      12.676  /haQSrjFlq30I60UVN1VsB6uRwKM.jpg   2019-09-13       92
# 9998      12.676  /dVbGeU5agxFGcJnL5hk4uO8W7i2.jpg   2014-08-01      139
# 9999      12.674  /33Z4AmHQYUpMWiM0T1jYq3xPdKI.jpg   2021-09-16       98
#
#                                                 tagline  \
# 0                                  The tide is turning.
# 1     Every good thing in this world started with a ...
# 2                         Be careful what you wish for.
# 3                                    Odd ducks welcome.
# 4                    Higher. Further. Faster. Together.
# ...                                                 ...
# 9995                               As big as the ocean!
# 9996                       Success is the best revenge.
# 9997                            Some Monsters Are Real.
# 9998                                The Funk Don't Quit
# 9999                                   No one's coming.
#
#                              title  vote_average  vote_count  \
# 0     Aquaman and the Lost Kingdom         7.013        1156
# 1                            Wonka         7.200        1660
# 2                             Wish         6.638         538
# 3                        Migration         7.830         390
# 4                      The Marvels         6.415        1328
# ...                            ...           ...         ...
# 9995              The Caine Mutiny         7.145         306
# 9996              Muriel's Wedding         6.868         413
# 9997                         Haunt         6.697        1086
# 9998                     Get on Up         6.763         489
# 9999                          Help         7.133          98
#
#                                                  actors             director  \
# 0     ['Jason Momoa', 'Patrick Wilson', 'Yahya Abdul...        ['James Wan']
# 1     ['Timothée Chalamet', 'Calah Lane', 'Keegan-Mi...        ['Paul King']
# 2     ['Ariana DeBose', 'Chris Pine', 'Alan Tudyk', ...       ['Chris Buck']
# 3     ['Kumail Nanjiani', 'Elizabeth Banks', 'Caspar...  ['Benjamin Renner']
# 4     ['Brie Larson', 'Teyonah Parris', 'Iman Vellan...      ['Nia DaCosta']
# ...                                                 ...                  ...
# 9995  ['Humphrey Bogart', 'Robert Francis', 'Van Joh...   ['Edward Dmytryk']
# 9996  ['Toni Collette', 'Bill Hunter', 'Rachel Griff...       ['P.J. Hogan']
# 9997  ['Katie Stevens', 'Will Brittain', 'Lauryn McC...       ['Scott Beck']
# 9998  ['Chadwick Boseman', 'Nelsan Ellis', 'Dan Aykr...      ['Tate Taylor']
# 9999  ['Jodie Comer', 'Stephen Graham', 'Ian Hart', ...      ['Marc Munden']
#
#                                                keywords
# 0     ['superhero', 'secret society', 'half-brother'...
# 1     ['chocolate', 'musical', 'prequel', 'duringcre...
# 2     ['friendship', 'musical', 'computer animation'...
# 3     ['duck', 'migration', 'flight', 'anthropomorph...
# 4     ['hero', 'superhero', 'space travel', 'based o...
# ...                                                 ...
# 9995  ['mutiny', 'post-traumatic stress disorder (pt...
# 9996  ['daughter', 'individual', 'friendship', 'drea...
# 9997  ['mask', 'halloween', 'haunted house', 'illino...
# 9998  ['vietnam war', '1970s', 'biography', 'south c...
# 9999    ['liverpool, england', 'care home', 'covid-19']
#
# [10000 rows x 19 columns]

# %%
movies['tags'] = movies['overview']+movies['genre']

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
#                                                  genre  \
# 0                                          Drama,Crime
# 1                                 Comedy,Drama,Romance
# 2                                          Drama,Crime
# 3                                    Drama,History,War
# 4                                          Drama,Crime
# ...                                                ...
# 9995                          Action,Adventure,Fantasy
# 9996  Action,TV Movie,Science Fiction,Comedy,Adventure
# 9997                        Action,Science Fiction,War
# 9998                    Adventure,Fantasy,Action,Drama
# 9999                             Thriller,Action,Crime
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
# [10000 rows x 5 columns]

# %%
new_data = movies.drop(columns= ['overview', 'genre'])

# %%
new_data
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
# [10000 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv =  CountVectorizer(max_features= 10000, stop_words= 'english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector = cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity= cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.05634362, 0.12888482, ..., 0.07559289, 0.11065667,
#         0.06388766],
#        [0.05634362, 1.        , 0.07624929, ..., 0.        , 0.03636965,
#         0.        ],
#        [0.12888482, 0.07624929, 1.        , ..., 0.02273314, 0.06655583,
#         0.08645856],
#        ...,
#        [0.07559289, 0.        , 0.02273314, ..., 1.        , 0.03253   ,
#         0.02817181],
#        [0.11065667, 0.03636965, 0.06655583, ..., 0.03253   , 1.        ,
#         0.0412393 ],
#        [0.06388766, 0.        , 0.08645856, ..., 0.02817181, 0.0412393 ,
#         1.        ]])

# %%
new_data[new_data['title'] =="The Godfather"].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse = True, key =lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City

# %%
def recommend(movies):
    index = new_data[new_data['title'] == movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].title)

# %%
recommend("Iron Man")
# Out:
# Iron Man
# Iron Man 3
# Guardians of the Galaxy Vol. 2
# Avengers: Age of Ultron
# Star Wars: Episode III - Revenge of the Sith

# %%
import pickle

# %%
pickle.dump(new_data, open('movies_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('movies_list.pkl', 'rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
# [10000 rows x 3 columns]
